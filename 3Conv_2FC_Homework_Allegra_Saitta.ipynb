jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space902.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space903.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space904.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space905.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space906.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space907.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space908.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space909.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space91.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space910.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space911.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space912.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space913.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space914.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space915.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space916.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space917.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space918.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space919.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space92.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space920.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space921.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space922.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space923.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space924.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space925.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space926.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space927.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space928.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space929.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space93.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space930.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space931.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space932.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space933.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space934.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space935.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space936.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space937.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space938.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space939.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space94.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space940.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space941.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space942.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space943.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space944.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space945.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space946.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space947.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space948.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space949.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space95.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space950.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space951.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space952.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space953.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space954.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space955.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space956.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space957.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space958.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space959.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space96.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space960.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space961.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space962.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space963.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space964.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space965.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space966.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space967.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space968.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space969.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space97.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space970.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space971.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space972.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space973.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space974.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space975.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space976.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space977.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space978.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space979.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space98.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space980.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space981.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space982.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space983.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space984.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space985.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space986.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space987.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space988.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space989.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space99.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space990.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space991.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space992.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space993.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space994.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space995.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space996.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space997.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space998.jpg
#   inflating: Train/asl_alphabet_train/asl_alphabet_train/space/space999.jpg

# %%
pip install split-folders tqdm
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
import splitfolders
! mkdir Subsets
splitfolders.ratio("/content/Train/asl_alphabet_train/asl_alphabet_train", output= "/content/Subsets", seed=1337, ratio=(.26, .74), group_prefix=None)
# Out:
# Copying files: 87000 files [00:15, 5502.81 files/s]

# %%
! mkdir asl-alphabet
splitfolders.ratio("/content/Subsets/train", output= "/content/asl-alphabet", seed=1337, ratio=(.76, .13, .11), group_prefix=None)
# Out:
# Copying files: 22620 files [00:03, 5702.25 files/s]

# %%
# %rm -rf /content/Train
# %rm -rf /content/Subsets
# %rm -rf /content/asl-alphabet.zip

# %%
import os
dest_dir = "/content/asl-alphabet"
os.listdir(dest_dir)
# Out:
# ['train', 'val', 'test']

# %%
def dt_info(path, types):
    cls_name=[]
    f_p_cl=[]
    totalClasses=0
    totalFiles=0
    for base, cls, files in os.walk(path):
        for Classes in cls:
            totalClasses += 1
            cls_name.append(Classes)
        for Files in files:
            totalFiles += 1
        f_p_cl.append(len(files))
    print(types, 'set description')
    print('Total Number of classes',totalClasses)
    print('Total Number of files',totalFiles)
    files_per_classes = dict(zip(cls_name, f_p_cl[1:]))
    return files_per_classes

# %%
dt_info('/content/asl-alphabet/train', types='train')
# Out:
# train set description
# Total Number of classes 29
# Total Number of files 17168
# {'A': 592,
#  'B': 592,
#  'C': 592,
#  'D': 592,
#  'E': 592,
#  'F': 592,
#  'G': 592,
#  'H': 592,
#  'I': 592,
#  'J': 592,
#  'K': 592,
#  'L': 592,
#  'M': 592,
#  'N': 592,
#  'O': 592,
#  'P': 592,
#  'Q': 592,
#  'R': 592,
#  'S': 592,
#  'T': 592,
#  'U': 592,
#  'V': 592,
#  'W': 592,
#  'X': 592,
#  'Y': 592,
#  'Z': 592,
#  'del': 592,
#  'nothing': 592,
#  'space': 592}

# %%
dt_info('/content/asl-alphabet/val', types='val')
# Out:
# val set description
# Total Number of classes 29
# Total Number of files 2929
# {'A': 101,
#  'B': 101,
#  'C': 101,
#  'D': 101,
#  'E': 101,
#  'F': 101,
#  'G': 101,
#  'H': 101,
#  'I': 101,
#  'J': 101,
#  'K': 101,
#  'L': 101,
#  'M': 101,
#  'N': 101,
#  'O': 101,
#  'P': 101,
#  'Q': 101,
#  'R': 101,
#  'S': 101,
#  'T': 101,
#  'U': 101,
#  'V': 101,
#  'W': 101,
#  'X': 101,
#  'Y': 101,
#  'Z': 101,
#  'del': 101,
#  'nothing': 101,
#  'space': 101}

# %%
dt_info('/content/asl-alphabet/test', types='test')
# Out:
# test set description
# Total Number of classes 29
# Total Number of files 2523
# {'A': 87,
#  'B': 87,
#  'C': 87,
#  'D': 87,
#  'E': 87,
#  'F': 87,
#  'G': 87,
#  'H': 87,
#  'I': 87,
#  'J': 87,
#  'K': 87,
#  'L': 87,
#  'M': 87,
#  'N': 87,
#  'O': 87,
#  'P': 87,
#  'Q': 87,
#  'R': 87,
#  'S': 87,
#  'T': 87,
#  'U': 87,
#  'V': 87,
#  'W': 87,
#  'X': 87,
#  'Y': 87,
#  'Z': 87,
#  'del': 87,
#  'nothing': 87,
#  'space': 87}

# %% [markdown]
# ## **Custom dataset**

# %%
import torch 
import torch.nn as nn
import torchvision.transforms as T
import torchvision.transforms.functional as TF 
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from PIL import Image 
from matplotlib import pyplot as plt

# %%
class MyDataset(Dataset):
  def __init__(self, dset_dir, train=True, val=False, transforms=T.Compose([])): 
    if train:
       split= "train"
    elif val:
       split="val"
    else:
      split="test"
        
    self.dset_dir = Path(dset_dir)/split
    self.transforms = transforms 

    self.files = [] 

    folders = sorted(os.listdir(self.dset_dir)) 
    for folder in folders:
      class_idx = folders.index(folder) 

      folder_dir = self.dset_dir/folder  

      files = os.listdir(folder_dir) 

      self.files += [{"file": folder_dir/x, "class": class_idx} for x in files] 

  def __len__(self):
    return len(self.files)

  def __getitem__(self, i):  
    item = self.files[i] 
    file = item['file'] 
    class_idx = torch.tensor(item['class']) 

    img = Image.open(file).convert("RGB") 
    img = self.transforms(img) 
    return img, class_idx

# %%
transforms = T.Compose([
        T.Resize((200,200)),
        T.ToTensor(),
        T.Normalize(0.5, 0.5) 
    ])

# %%
train_dset = MyDataset(dest_dir, train=True, val=False, transforms=transforms)
val_dset = MyDataset(dest_dir, train=False, val=True, transforms=transforms)
test_dset = MyDataset(dest_dir, train=False, val=False, transforms=transforms)

# %%
data, label = train_dset[0] 
print(data.shape)
# Out:
# torch.Size([3, 200, 200])

# %%
train_loader = DataLoader(train_dset, batch_size=64, shuffle=True, drop_last=True, num_workers=2) 
val_loader = DataLoader(val_dset, batch_size=64, shuffle=False, drop_last=False, num_workers=2)
test_loader = DataLoader(test_dset, batch_size=64, shuffle=False, drop_last=False, num_workers=2)

# %%
inputs, labels = next(iter(train_loader))
print(inputs.shape) 
print(labels.shape)
# Out:
# torch.Size([64, 3, 200, 200])
# torch.Size([64])

# %% [markdown]
# ## **Classification**

# %%
class MyCNN(nn.Module):

  #Constructor
  def __init__(self, in_size=3, out_size=29, use_norm=False): 
    # Call parent contructor
    super().__init__()
    self.conv_layers = nn.Sequential(
      # Layer 1
      nn.Conv2d(in_channels=in_size, out_channels=8, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      # Layer 2
      nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2, stride=2), 
      # Layer 3
      nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2, stride=2)
    )

  # Forward 
  def forward(self, x):
    x = self.conv_layers(x)
    return x

# %%
# Create the model
model = MyCNN()
print(model)
# Out:
# MyCNN(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %%
test_x, _ = train_dset[0]

# %%
test_x.size()
# Out:
# torch.Size([3, 200, 200])

# %%
test_x = test_x.unsqueeze(dim=0) 
test_x.size()
# Out:
# torch.Size([1, 3, 200, 200])

# %%
output = model(test_x)
output.shape
# Out:
# torch.Size([1, 32, 50, 50])

# %%
out_features = output.size(1) * output.size(2) * output.size(3)
print(out_features)
# Out:
# 80000

# %%
class CNN(nn.Module):

 #Constructor
 def __init__(self, in_size=3, out_size=29, use_norm=False): 
    # Call parent contructor
    super().__init__()
    self.conv_layers = nn.Sequential(
      # Layer 1
      nn.Conv2d(in_channels=in_size, out_channels=8, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      # Layer 2
      nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2, stride=2), 
      # Layer 3
      nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1, stride=1),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2, stride=2)
    )

    # Create fully-connected layers
    self.fc_layers = nn.Sequential(
        # a first FC layer
        nn.Linear(80000, 4096),
        nn.ReLU(),
        # a second FC layer
        nn.Linear(4096, 1024),
        nn.ReLU(),
        # the final Classification Layer
        nn.Linear(1024, 29)
    )

 # Forward
 def forward(self, x):
    x = self.conv_layers(x) 
    x = x.view(x.size(0), -1) 
    output = self.fc_layers(x) 
    return output

# %%
model = CNN()
output = model(test_x)
output.shape
# Out:
# torch.Size([1, 29])

# %%
def train(net, loaders, optimizer, criterion, epochs=100, device=torch.device('cpu')):
    try:
        net = net.to(device)
        print(net)
        # Initialize history
        history_loss = {"train": [], "val": [], "test": []} 
        history_accuracy = {"train": [], "val": [], "test": []} 
        # Process each epoch
        for epoch in range(epochs):
            print(f"Running epoch: {epoch}")
            # Initialize epoch variables
            sum_loss = {"train": 0, "val": 0, "test": 0}
            sum_accuracy = {"train": 0, "val": 0, "test": 0}
            # Process each split
            for split in ["train", "val", "test"]:
                if split== "train":
                   net.train()
                else:
                  net.eval()
                # Process each batch
                for (input, labels) in loaders[split]:
                    # Move to CUDA 
                    input = input.to(device)
                    labels = labels.to(device)
                    # Reset gradients
                    optimizer.zero_grad()
                    # Compute output
                    pred = net(input)
                    loss = criterion(pred, labels) 
                    # Update loss
                    sum_loss[split] += loss.item()
                    # Check parameter update
                    if split == "train":
                        # Compute gradients
                        loss.backward()
                        # Optimize
                        optimizer.step()
                    # Compute accuracy
                    _,pred_labels = pred.max(1) 
                    batch_accuracy = (pred_labels == labels).sum().item()/input.size(0) 
                    # Update accuracy
                    sum_accuracy[split] += batch_accuracy
            # Compute epoch loss/accuracy
            epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}
            epoch_accuracy = {split: sum_accuracy[split]/len(loaders[split]) for split in ["train", "val", "test"]}
            # Update history
            for split in ["train", "val", "test"]:
                history_loss[split].append(epoch_loss[split])
                history_accuracy[split].append(epoch_accuracy[split])
            # Print info - f is a formatted string
            print(f"Epoch {epoch+1}:",
                  f"TrL={epoch_loss['train']:.4f},",
                  f"TrA={epoch_accuracy['train']:.4f},",
                  f"VL={epoch_loss['val']:.4f},",
                  f"VA={epoch_accuracy['val']:.4f},",
                  f"TeL={epoch_loss['test']:.4f},",
                  f"TeA={epoch_accuracy['test']:.4f},")
    except KeyboardInterrupt:
        print("Interrupted")
    finally:
        # Plot loss
        plt.title("Loss")
        for split in ["train", "val", "test"]:
            plt.plot(history_loss[split], label=split)
        plt.legend()
        plt.show()
        # Plot accuracy
        plt.title("Accuracy")
        for split in ["train", "val", "test"]:
            plt.plot(history_accuracy[split], label=split)
        plt.legend()
        plt.show()

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

net = CNN() 
optimizer = optim.SGD(net.parameters(), lr = 0.05)
criterion = nn.CrossEntropyLoss()

# Define dictionary of loaders
loaders = {"train": train_loader,
           "val": val_loader,
           "test": test_loader}

train(net, loaders, optimizer, criterion, epochs=10, device=device)
# Out:
# CNN(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=80000, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4096, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=29, bias=True)
#   )
# )
# Running epoch: 0
# Epoch 1: TrL=3.1129, TrA=0.1102, VL=2.4821, VA=0.2425, TeL=2.4456, TeA=0.2550,
# Running epoch: 1
# Epoch 2: TrL=2.0081, TrA=0.3632, VL=1.5245, VA=0.4865, TeL=1.4643, TeA=0.4926,
# Running epoch: 2
# Epoch 3: TrL=1.3627, TrA=0.5571, VL=1.0786, VA=0.6276, TeL=1.0566, TeA=0.6458,
# Running epoch: 3
# Epoch 4: TrL=1.0061, TrA=0.6694, VL=0.8530, VA=0.7059, TeL=0.8036, TeA=0.7265,
# Running epoch: 4
# Epoch 5: TrL=0.7458, TrA=0.7495, VL=0.6788, VA=0.7663, TeL=0.6675, TeA=0.7688,
# Running epoch: 5
# Epoch 6: TrL=0.5624, TrA=0.8065, VL=0.5553, VA=0.8193, TeL=0.5342, TeA=0.8191,
# Running epoch: 6
# Epoch 7: TrL=0.3979, TrA=0.8625, VL=0.5685, VA=0.8174, TeL=0.5596, TeA=0.8259,
# Running epoch: 7
# Epoch 8: TrL=0.3012, TrA=0.9024, VL=0.4417, VA=0.8594, TeL=0.3947, TeA=0.8737,
# Running epoch: 8
# Epoch 9: TrL=0.2437, TrA=0.9205, VL=0.2110, VA=0.9319, TeL=0.2229, TeA=0.9273,
# Running epoch: 9
# Epoch 10: TrL=0.2066, TrA=0.9363, VL=0.2122, VA=0.9293, TeL=0.2036, TeA=0.9334,
